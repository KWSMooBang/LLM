# %% [markdown]
# ### SQL 생성 프롬프트

# %%
def make_prompt(ddl, question, query=""):
    prompt = f"""
당신은 SQL을 생성하는 SQL 봇입니다. DDL의 테이블을 활용한 Question을 해결할 수 있는 SQL 쿼리를 생성하세요.
### DDL:
{ddl}

 ### Question:
{question}

### SQL:
{query}
"""

    return prompt

# %%
example1 = make_prompt(
    ddl="""CREATE TABLE messages (
        "message_id" SERIAL PRIMARY KEY,
        "conversation_id" INT NOT NULL,
        "sender_id" INT NOT NULL,
        "content" TEXT,
        "timestamp" TIMESTAMP WITH TIME ZONE DEFAULT CURRENT_TIMESTAMP,
        "read" BOOLEAN DEFAULT FALSE,
        FOREIGN KEY ("conversation_id") REFERENCES conversations("conversation_id"),
        FOREIGN KEY ("sender_id") REFERENCES users("user_id")
    );""",
    question="messages 테이블에서 모든 데이터를 조회해 줘",
    query="SELECT * FROM messages;"
)
print(example1)
# Out:
# 당신은 SQL을 생성하는 SQL 봇입니다. DDL의 테이블을 활용한 Question을 해결할 수 있는 SQL 쿼리를 생성하세요.
# ### DDL:
# CREATE TABLE messages (
#         "message_id" SERIAL PRIMARY KEY,
#         "conversation_id" INT NOT NULL,
#         "sender_id" INT NOT NULL,
#         "content" TEXT,
#         "timestamp" TIMESTAMP WITH TIME ZONE DEFAULT CURRENT_TIMESTAMP,
#         "read" BOOLEAN DEFAULT FALSE,
#         FOREIGN KEY ("conversation_id") REFERENCES conversations("conversation_id"),
#         FOREIGN KEY ("sender_id") REFERENCES users("user_id")
#     );
#
#  ### Question:
# messages 테이블에서 모든 데이터를 조회해 줘
#
# ### SQL:
# SELECT * FROM messages;

# %% [markdown]
# ### GPT-4 평가 프롬프트와 코드 준비

# %%
import json
from pathlib import Path


def make_requests_for_gpt_evaluation(df, filename, dir='requests'):
    if not Path(dir).exists():
        Path(dir).mkdir(parents=True)
    prompts = []
    for idx, row in df.iterrows():
        prompts.append("""Based on below DDL and Question, evaluate gen_sql can resolve Questions.
If gen_sql do equal job, return "yes" else return "no".
Output JSON Format: {"resolve_yn": ""}""" + f"""

DDL: {row['context']}
Question: {row['question']}
gt_sql: {row['answer']}
gen_sql: {row['gen_sql']}"""
)
    jobs = [
        {
            "model": "gpt-4-turbo-preview", 
            "response_format": {"type": "json_object"},
            "messages": [{"role": "system", "content": prompt}]
        }
        for prompt in prompts
    ]
    with open(Path(dir, filename), 'w') as f:
        for job in jobs:
            json_string = json.dumps(job)
            f.write(json_string + '\n')

# %%
import os
os.environ["OPENAI_API_KEY"] = "Your OpenAI API key"
"""
python api_request_parallel_processor.py \
    --requests_filepath {요청 파일 경로} \
    --save_filepath {생성할 결과 파일 경로} \
    --request_url https://api.openai.com/v1/chat/completions \
    --max_requests_per_minute 300 \
    --max_tokens_per_minute 100000 \
    --token_encoding_name cl100k_base \
    --max_attempts 5 \
    --logging_level 20
"""
# Out:
# '\npython api_request_parallel_processor.py     --requests_filepath {요청 파일 경로}     --save_filepath {생성할 결과 파일 경로}     --request_url https://api.openai.com/v1/chat/completions     --max_requests_per_minute 300     --max_tokens_per_minute 100000     --token_encoding_name cl100k_base     --max_attempts 5     --logging_level 20\n'

# %%
import pandas as pd

def change_jsonl_to_csv(input_file, output_file, prompt_column="prompt", response_column="response"):
    prompts = []
    responses =[]
    with open(input_file, 'r') as json_file:
        for data in json_file:
            prompts.append(json.loads(data)[0]['messages'][0]['content'])
            responses.append(json.loads(data)[1]['choices'][0]['message']['content'])
    
    df = pd.DataFrame({prompt_column: prompts, response_column: responses})
    df.to_csv(output_file, index=False)
    return df

# %% [markdown]
# ### 미세 조정 수행하기

# %%
import torch
from transformers import pipeline, AutoTokenizer, AutoModelForCausalLM

def make_inference_pipeline(model_name):
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForCausalLM.from_pretrained(model_name, device_map='auto', load_in_4bit=True, bnb_4bit_compute_dtype=torch.float16)
    pipe = pipeline("text-generation", model=model, tokenizer=tokenizer)
    return pipe

model_name = 'beomi/Yi-Ko-6B'
hf_pipe = make_inference_pipeline(model_name)

example = """당신은 SQL을 생성하는 SQL 봇입니다. DDL의 테이블을 활용한 Question을 해결할 수 있는 SQL 쿼리를 생성하세요.

### DDL:
CREATE TABLE players (
    player_id INT PRIMARY KEY AUTO_INCREMENT,
    username VARCHAR(255) UNIQUE NOT NULL,
    email VARCHAR(255) UNIQUE NOT NULL,
    password_hash VARCHAR(255) NOT NULL,
    date_joined DATETIME NOT NULL,
    last_login DATETIME
);

 ### Question:
사용자 이름에 'admin'이 포함되어 있는 계정의 수를 알려주세요.

### SQL:
"""

hf_pipe(example, do_sample=False, return_full_text=False, max_length=1024, truncation=True)
# SELECT COUNT(*) FROM players WHERE username LIKE '%admin%';
# 
# ### SQL 봇:
# SELECT COUNT(*) FROM players WHERE username LIKE '%admin%';
# 
# ### SQL 봇의 결과:
# 사용자 이름에 'admin'이 포함되어 있는 계정의 수는 1개입니다.
# Out:
# 2024-11-15 14:07:19.668909: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-15 14:07:19.668982: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-15 14:07:19.866230: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-15 14:07:20.318441: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-15 14:07:23.488693: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# [{'generated_text': "SELECT COUNT(*) FROM players WHERE username LIKE '%admin%';\n\n### SQL 봇:\nSELECT COUNT(*) FROM players WHERE username LIKE '%admin%';\n\n### SQL 봇의 결과:\n사용자 이름에 'admin'이 포함되어 있는 계정의 수는 1개입니다."}]

# %%
from datasets import load_dataset

# 데이터셋 불러오기
df = load_dataset("shangrilar/ko_text2sql", "origin")['test']
df = df.to_pandas()
for idx, row in df.iterrows():
    prompt = make_prompt(row['context'], row['question'])
    df.loc[idx, 'prompt'] = prompt
# sql 생성
gen_sqls = hf_pipe(df['prompt'].tolist(), do_sample=False,
                                return_full_text=False, max_length=1024, truncation=True)
gen_sqls = [x[0]['generated_text'] for x in gen_sqls]
df['gen_sql'] = gen_sqls

# %%
# 평가를 위한 requests.jsonl 생성
eval_filepath = "text2sql_evaluation.jsonl"
make_requests_for_gpt_evaluation(df, eval_filepath)
# GPT-4 평가 수행
# !python api_request_parallel_processor.py \
    --requests_filepath requests/{eval_filepath} \
    --save_filepath results/{eval_filepath} \
    --request_url https://api.openai.com/v1/chat/completions \
    --max_requests_per_minute 2500 \
    --max_tokens_per_minute 100000 \
    --token_encoding_name cl100k_base \
    --max_attempts 5 \
    --logging_level 20
# Out:
# INFO:root:Starting request #0
# INFO:root:Starting request #1
# INFO:root:Starting request #2
# INFO:root:Starting request #3
# INFO:root:Starting request #4
# INFO:root:Starting request #5
# INFO:root:Starting request #6
# INFO:root:Starting request #7
# INFO:root:Starting request #8
# INFO:root:Starting request #9
# INFO:root:Starting request #10
# INFO:root:Starting request #11
# INFO:root:Starting request #12
# INFO:root:Starting request #13
# INFO:root:Starting request #14
# INFO:root:Starting request #15
# INFO:root:Starting request #16
# INFO:root:Starting request #17
# INFO:root:Starting request #18
# INFO:root:Starting request #19
# INFO:root:Starting request #20
# INFO:root:Starting request #21
# INFO:root:Starting request #22
# INFO:root:Starting request #23
# INFO:root:Starting request #24
# INFO:root:Starting request #25
# INFO:root:Starting request #26
# INFO:root:Starting request #27
# INFO:root:Starting request #28
# INFO:root:Starting request #29
# INFO:root:Starting request #30
# INFO:root:Starting request #31
# INFO:root:Starting request #32
# INFO:root:Starting request #33
# INFO:root:Starting request #34
# INFO:root:Starting request #35
# INFO:root:Starting request #36
# INFO:root:Starting request #37
# INFO:root:Starting request #38
# INFO:root:Starting request #39
# INFO:root:Starting request #40
# INFO:root:Starting request #41
# INFO:root:Starting request #42
# INFO:root:Starting request #43
# INFO:root:Starting request #44
# INFO:root:Starting request #45
# INFO:root:Starting request #46
# INFO:root:Starting request #47
# INFO:root:Starting request #48
# INFO:root:Starting request #49
# INFO:root:Starting request #50
# INFO:root:Starting request #51
# INFO:root:Starting request #52
# INFO:root:Starting request #53
# INFO:root:Starting request #54
# INFO:root:Starting request #55
# INFO:root:Starting request #56
# INFO:root:Starting request #57
# INFO:root:Starting request #58
# INFO:root:Starting request #59
# INFO:root:Starting request #60
# INFO:root:Starting request #61
# INFO:root:Starting request #62
# INFO:root:Starting request #63
# INFO:root:Starting request #64
# INFO:root:Starting request #65
# INFO:root:Starting request #66
# INFO:root:Starting request #67
# INFO:root:Starting request #68
# INFO:root:Starting request #69
# INFO:root:Starting request #70
# INFO:root:Starting request #71
# INFO:root:Starting request #72
# INFO:root:Starting request #73
# INFO:root:Starting request #74
# INFO:root:Starting request #75
# INFO:root:Starting request #76
# INFO:root:Starting request #77
# INFO:root:Starting request #78
# INFO:root:Starting request #79
# INFO:root:Starting request #80
# INFO:root:Starting request #81
# INFO:root:Starting request #82
# INFO:root:Starting request #83
# INFO:root:Starting request #84
# INFO:root:Starting request #85
# INFO:root:Starting request #86
# INFO:root:Starting request #87
# INFO:root:Starting request #88
# INFO:root:Starting request #89
# INFO:root:Starting request #90
# INFO:root:Starting request #91
# INFO:root:Starting request #92
# INFO:root:Starting request #93
# INFO:root:Starting request #94
# INFO:root:Starting request #95
# INFO:root:Starting request #96
# INFO:root:Starting request #97
# INFO:root:Starting request #98
# INFO:root:Starting request #99
# INFO:root:Starting request #100
# INFO:root:Starting request #101
# INFO:root:Starting request #102
# INFO:root:Starting request #103
# INFO:root:Starting request #104
# INFO:root:Starting request #105
# INFO:root:Starting request #106
# INFO:root:Starting request #107
# WARNING:root:Request 10 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 63 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 60 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 55 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 68 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 66 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 67 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 8 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 65 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 59 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #108
# WARNING:root:Request 79 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 71 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 74 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 3 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 6 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 69 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 97 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 83 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 84 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 9 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 76 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 78 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 70 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 81 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 7 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 73 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 13 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 4 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 95 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 11 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 1 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 93 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 85 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 45 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 24 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 16 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 88 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 15 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 82 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 25 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 5 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 20 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 100 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 91 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 87 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 34 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 22 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 2 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 102 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 96 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 14 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 103 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 86 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 18 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 12 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 89 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 94 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 21 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 38 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 23 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 105 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 101 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 92 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 104 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 17 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 28 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 26 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 106 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 98 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 27 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 42 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 107 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 29 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 32 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 36 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 108 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 30 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 43 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 40 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 39 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 50 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 37 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 33 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 31 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 49 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 47 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 72 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 51 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 41 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 48 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 46 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 54 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 44 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 64 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 52 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 61 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 57 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 62 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 53 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 56 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 58 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 77 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 80 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 0 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 19 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 75 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 99 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 90 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #10
# WARNING:root:Request 35 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 10 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #63
# WARNING:root:Request 63 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #60
# WARNING:root:Request 60 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #55
# WARNING:root:Request 55 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #68
# WARNING:root:Request 68 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #66
# WARNING:root:Request 66 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #67
# WARNING:root:Request 67 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #8
# INFO:root:Starting request #65
# WARNING:root:Request 8 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #59
# WARNING:root:Request 65 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 59 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #79
# WARNING:root:Request 79 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #71
# WARNING:root:Request 71 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #74
# WARNING:root:Request 74 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #3
# WARNING:root:Request 3 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #6
# WARNING:root:Request 6 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #69
# WARNING:root:Request 69 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #97
# WARNING:root:Request 97 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #83
# WARNING:root:Request 83 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #84
# WARNING:root:Request 84 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #9
# WARNING:root:Request 9 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #76
# WARNING:root:Request 76 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #78
# WARNING:root:Request 78 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #70
# WARNING:root:Request 70 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #81
# WARNING:root:Request 81 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #7
# WARNING:root:Request 7 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #73
# WARNING:root:Request 73 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #13
# WARNING:root:Request 13 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #4
# WARNING:root:Request 4 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #95
# INFO:root:Starting request #11
# WARNING:root:Request 95 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 11 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #1
# WARNING:root:Request 1 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #93
# WARNING:root:Request 93 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #85
# WARNING:root:Request 85 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #45
# WARNING:root:Request 45 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #24
# WARNING:root:Request 24 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #16
# WARNING:root:Request 16 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #88
# WARNING:root:Request 88 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #15
# WARNING:root:Request 15 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #82
# WARNING:root:Request 82 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #25
# WARNING:root:Request 25 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #5
# WARNING:root:Request 5 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #20
# WARNING:root:Request 20 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #100
# WARNING:root:Request 100 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #91
# WARNING:root:Request 91 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #87
# WARNING:root:Request 87 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #34
# WARNING:root:Request 34 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #22
# WARNING:root:Request 22 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #2
# WARNING:root:Request 2 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #102
# WARNING:root:Request 102 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #96
# WARNING:root:Request 96 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #14
# WARNING:root:Request 14 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #103
# WARNING:root:Request 103 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #86
# WARNING:root:Request 86 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #18
# WARNING:root:Request 18 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #12
# WARNING:root:Request 12 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #89
# WARNING:root:Request 89 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #94
# WARNING:root:Request 94 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #21
# WARNING:root:Request 21 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #38
# WARNING:root:Request 38 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #23
# WARNING:root:Request 23 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #105
# WARNING:root:Request 105 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #101
# WARNING:root:Request 101 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #92
# WARNING:root:Request 92 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #104
# WARNING:root:Request 104 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #17
# WARNING:root:Request 17 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #28
# WARNING:root:Request 28 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #26
# WARNING:root:Request 26 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #106
# WARNING:root:Request 106 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #98
# WARNING:root:Request 98 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #27
# WARNING:root:Request 27 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #42
# WARNING:root:Request 42 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #107
# WARNING:root:Request 107 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #29
# WARNING:root:Request 29 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #32
# WARNING:root:Request 32 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #36
# WARNING:root:Request 36 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #108
# WARNING:root:Request 108 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #30
# INFO:root:Starting request #43
# WARNING:root:Request 30 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# WARNING:root:Request 43 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #40
# WARNING:root:Request 40 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #39
# WARNING:root:Request 39 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #50
# WARNING:root:Request 50 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #37
# WARNING:root:Request 37 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #33
# WARNING:root:Request 33 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #31
# WARNING:root:Request 31 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #49
# WARNING:root:Request 49 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #47
# WARNING:root:Request 47 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #72
# WARNING:root:Request 72 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #51
# WARNING:root:Request 51 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #41
# ...
# INFO:root:Starting request #110
# WARNING:root:Request 110 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #109
# WARNING:root:Request 109 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #110
# WARNING:root:Request 110 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #109
# WARNING:root:Request 109 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #110
# WARNING:root:Request 110 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #109
# WARNING:root:Request 109 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# ERROR:root:Request {'model': 'gpt-4-turbo-preview', 'response_format': {'type': 'json_object'}, 'messages': [{'role': 'system', 'content': 'Based on below DDL and Question, evaluate gen_sql can resolve Questions.\nIf gen_sql do equal job, return "yes" else return "no".\nOutput JSON Format: {"resolve_yn": ""}\n\nDDL: CREATE TABLE npcs (\n  npc_id INT PRIMARY KEY AUTO_INCREMENT,\n  name VARCHAR(255) NOT NULL,\n  role VARCHAR(255),\n  location VARCHAR(255),\n  related_quest INT,\n  FOREIGN KEY (related_quest) REFERENCES quests(quest_id)\n);\nQuestion: 각 역할별로 npc의 총 수를 알려주세요.\ngt_sql: SELECT role, COUNT(npc_id) FROM npcs GROUP BY role;\ngen_sql: SELECT COUNT(*) FROM npcs\n\n### SQL 봇의 특징:\n\n1. SQL 봇은 SQL 쿼리를 생성합니다.\n2. SQL 봇은 SQL 쿼리를 생성할 때, SQL 쿼리의 조건을 입력할 수 있습니다.\n3. SQL 봇은 SQL 쿼리의 조건을 입력할 때, SQL 쿼리의 조건을 SQL 쿼리의 조건에 따라 입력할 수 있습니다.\n4. SQL 봇은 SQL 쿼리의 조건을 입력할 때, SQL 쿼리의 조건을 SQL 쿼리의 조건에 따라 입력할 수 있습니다.\n5. SQL 봇은 SQL 쿼리의 조건을 입력할 때, SQL 쿼리의 조건을 SQL 쿼리의 조건에 따라 입력할 수 있습니다.\n6. SQL 봇은 SQL 쿼리의 조건을 입력할 때, SQL 쿼리의 조건을 SQL 쿼리의 조건에 따라 입력할 수 있습니다.\n7. SQL 봇은 SQL 쿼리의 조건을 입력할 때, SQL 쿼리의 조건을 SQL 쿼리의 조건에 따라 입력할 수 있습니다.\n8. SQL 봇은 SQL 쿼리의 조건을 입력할 때, SQL 쿼리의 조건을 SQL 쿼리의 조건에 따라 입력할 수 있습니다.\n9. SQL 봇은 SQL 쿼리의 조건을 입력할 때, SQL 쿼리의 조건을 SQL 쿼리의 조건에 따라 입력할 수 있습니다.\n10. SQL 봇은 SQL 쿼리의 조건을 입력할 때, SQL 쿼리의 조건을 SQL 쿼리의 조건에 따라 입력할 수 있습니다.\n11. SQL 봇은 SQL 쿼리의 조건을 입력할 때, SQL 쿼리의 조건을 SQL 쿼리의 조건에 따라 입력할 수 있습니다.\n12. SQL 봇은 SQL 쿼리의 조건을 입력할 때, SQL 쿼리의 조건을 SQL 쿼리의 조건에 따라 입력할 수 있습니다.\n13. SQL 봇은 SQL 쿼리의 조건을 입력할 때, SQL 쿼리의 조건을 SQL 쿼리의 조건에 따라 입력할 수 있습니다.\n14. SQL 봇은 SQL 쿼리의 조건을 입력할 때, SQL 쿼리의 조건을 SQL 쿼리의 조건에 따라 입력할 수 있습니다.\n15. SQL 봇은 SQL 쿼리의 조건을 입력할 때, SQL 쿼리의 조건을 SQL 쿼리의 조건에 따라 입력할 수 있습니다.\n16. SQL 봇은 SQL 쿼리의 조건을 입력할 때, SQL 쿼리의 조건을 SQL 쿼리의 조건에 따라 입력할 수 있습니다.\n17. SQL 봇은 SQL 쿼리의 조건을 입력할 때, SQL 쿼리의 조건을 SQL 쿼리의 조건에 따라 입력할 수 있습니다.\n18. SQL 봇은 SQL 쿼리의 조건을 입력할 때, SQL 쿼리의 조건을 SQL 쿼리의 조건에 따라 입력할 수 있습니다.\n19. SQL 봇은 SQL 쿼리의 조건을 입력할 때, SQL 쿼리의 조건을 SQL 쿼리의 조건에 따라 입력할 수 있습니다.\n20. SQL 봇은 SQL 쿼리의 조건을 입력할 때, SQL 쿼리의 조건을 SQL 쿼리의 조건에 따라 입력할 수 있습니다.\n21. SQL 봇은 SQL 쿼리의 조건을 입력할 때, SQL 쿼리의 조건을 SQL 쿼리의 조건에 따라 입력할 수 있습니다.\n22. SQL 봇은 SQL 쿼리의 조건을 입력할 때, SQL 쿼리의 조건을 SQL 쿼리의 조건에 따라 입력할 수 있습니다.\n23. SQL 봇은 SQL 쿼리의 조건을 입력할 때, SQL 쿼리의 조건을 SQL 쿼리의 조건에 따라 입력할 수 있습니다.\n24. SQL 봇은 SQL 쿼리의 조건을 입력할'}]} failed after all attempts. Saving errors: [{'error': {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}, {'error': {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}, {'error': {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}, {'error': {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}, {'error': {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}]
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-1451' coro=<APIRequest.call_api() done, defined at /home/woosungkim/projects/deep_learning/textbook/LLM/ch06/api_request_parallel_processor.py:302> exception=FileNotFoundError(2, 'No such file or directory')>
# Traceback (most recent call last):
#   File "/home/woosungkim/projects/deep_learning/textbook/LLM/ch06/api_request_parallel_processor.py", line 351, in call_api
#     append_to_jsonl(data, save_filepath)
#   File "/home/woosungkim/projects/deep_learning/textbook/LLM/ch06/api_request_parallel_processor.py", line 383, in append_to_jsonl
#     with open(filename, "a") as f:
#          ^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'results/text2sql_evaluation.jsonl'
# INFO:root:Starting request #110
# WARNING:root:Request 110 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# ERROR:root:Request {'model': 'gpt-4-turbo-preview', 'response_format': {'type': 'json_object'}, 'messages': [{'role': 'system', 'content': 'Based on below DDL and Question, evaluate gen_sql can resolve Questions.\nIf gen_sql do equal job, return "yes" else return "no".\nOutput JSON Format: {"resolve_yn": ""}\n\nDDL: CREATE TABLE characters (\n  character_id INT PRIMARY KEY AUTO_INCREMENT,\n  player_id INT NOT NULL,\n  name VARCHAR(255) NOT NULL,\n  level INT NOT NULL,\n  experience BIGINT NOT NULL,\n  character_class VARCHAR(255) NOT NULL,\n  FOREIGN KEY (player_id) REFERENCES players(player_id)\n);\nCREATE TABLE equipments (\n  equipment_id INT PRIMARY KEY AUTO_INCREMENT,\n  character_id INT NOT NULL,\n  item_name VARCHAR(255) NOT NULL,\n  equipped BOOLEAN NOT NULL,\n  FOREIGN KEY (character_id) REFERENCES characters(character_id)\n);\nQuestion: 장비가 장착된 상태인 캐릭터의 플레이어 ID와 아이템 이름을 나열하십시오.\ngt_sql: SELECT T1.player_id, T2.item_name FROM characters AS T1 JOIN equipments AS T2 ON T1.character_id = T2.character_id WHERE T2.equipped = TRUE;\ngen_sql: SELECT player_id, item_name FROM characters\nWHERE equipped = 1\nORDER BY player_id\n\n### SQL 봇의 특징:\n\n1. SQL 봇은 SQL 쿼리를 생성하는 봇입니다.\n2. SQL 봇은 SQL 쿼리를 생성하는 봇입니다.\n3. SQL 봇은 SQL 쿼리를 생성하는 봇입니다.\n4. SQL 봇은 SQL 쿼리를 생성하는 봇입니다.\n5. SQL 봇은 SQL 쿼리를 생성하는 봇입니다.\n6. SQL 봇은 SQL 쿼리를 생성하는 봇입니다.\n7. SQL 봇은 SQL 쿼리를 생성하는 봇입니다.\n8. SQL 봇은 SQL 쿼리를 생성하는 봇입니다.\n9. SQL 봇은 SQL 쿼리를 생성하는 봇입니다.\n10. SQL 봇은 SQL 쿼리를 생성하는 봇입니다.\n11. SQL 봇은 SQL 쿼리를 생성하는 봇입니다.\n12. SQL 봇은 SQL 쿼리를 생성하는 봇입니다.\n13. SQL 봇은 SQL 쿼리를 생성하는 봇입니다.\n14. SQL 봇은 SQL 쿼리를 생성하는 봇입니다.\n15. SQL 봇은 SQL 쿼리를 생성하는 봇입니다.\n16. SQL 봇은 SQL 쿼리를 생성하는 봇입니다.\n17. SQL 봇은 SQL 쿼리를 생성하는 봇입니다.\n18. SQL 봇은 SQL 쿼리를 생성하는 봇입니다.\n19. SQL 봇은 SQL 쿼리를 생성하는 봇입니다.\n20. SQL 봇은 SQL 쿼리를 생성하는 봇입니다.\n21. SQL 봇은 SQL 쿼리를 생성하는 봇입니다.\n22. SQL 봇은 SQL 쿼리를 생성하는 봇입니다.\n23. SQL 봇은 SQL 쿼리를 생성하는 봇입니다.\n24. SQL 봇은 SQL 쿼리를 생성하는 봇입니다.\n25. SQL 봇은 SQL 쿼리를 생성하는 봇입니다.\n26. SQL 봇은 SQL 쿼리를 생성하는 봇입니다.\n27. SQL 봇은 SQL 쿼리를 생성하는 봇입니다.\n28. SQL 봇은 SQL 쿼리를 생성하는 봇입니다.\n29. SQL 봇은 SQL 쿼리를 생성하는 봇입니다.\n30. SQL 봇은 SQL 쿼리를 생성하는 봇입니다.\n31. SQL 봇은 SQL 쿼리를 생성하는 봇입니다.\n32. SQL 봇은 SQL 쿼리를 생성하는 봇입니다.\n33. SQL 봇은 SQL 쿼리를 생성하는 봇입니다.\n34. SQL 봇은 SQL 쿼리를 생성하는 봇입니다.\n35. SQL 봇은 SQL 쿼리를 생성하는 봇입니다.\n36. SQL 봇은 SQL 쿼리를 생성하는 봇입니다.\n37. SQL 봇은 SQL 쿼리를 생성하는 봇입니다.\n38. SQL 봇은 SQL 쿼리를 생성하는 봇입니다.\n39. SQL 봇은 SQL 쿼리를 생성하는 봇입니다.\n40. SQL 봇'}]} failed after all attempts. Saving errors: [{'error': {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}, {'error': {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}, {'error': {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}, {'error': {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}, {'error': {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}]
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-1453' coro=<APIRequest.call_api() done, defined at /home/woosungkim/projects/deep_learning/textbook/LLM/ch06/api_request_parallel_processor.py:302> exception=FileNotFoundError(2, 'No such file or directory')>
# Traceback (most recent call last):
#   File "/home/woosungkim/projects/deep_learning/textbook/LLM/ch06/api_request_parallel_processor.py", line 351, in call_api
#     append_to_jsonl(data, save_filepath)
#   File "/home/woosungkim/projects/deep_learning/textbook/LLM/ch06/api_request_parallel_processor.py", line 383, in append_to_jsonl
#     with open(filename, "a") as f:
#          ^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'results/text2sql_evaluation.jsonl'
# INFO:root:Starting request #111
# WARNING:root:Request 111 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #111
# WARNING:root:Request 111 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #111
# WARNING:root:Request 111 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #111
# WARNING:root:Request 111 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# INFO:root:Starting request #111
# WARNING:root:Request 111 failed with error {'message': 'The model `gpt-4-turbo-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}
# ERROR:root:Request {'model': 'gpt-4-turbo-preview', 'response_format': {'type': 'json_object'}, 'messages': [{'role': 'system', 'content': 'Based on below DDL and Question, evaluate gen_sql can resolve Questions.\nIf gen_sql do equal job, return "yes" else return "no".\nOutput JSON Format: {"resolve_yn": ""}\n\nDDL: CREATE TABLE characters (\n  character_id INT PRIMARY KEY AUTO_INCREMENT,\n  player_id INT NOT NULL,\n  name VARCHAR(255) NOT NULL,\n  level INT NOT NULL,\n  experience BIGINT NOT NULL,\n  character_class VARCHAR(255) NOT NULL,\n  FOREIGN KEY (player_id) REFERENCES players(player_id)\n);\nCREATE TABLE inventory_items (\n  inventory_id INT PRIMARY KEY AUTO_INCREMENT,\n  character_id INT NOT NULL,\n  item_name VARCHAR(255) NOT NULL,\n  quantity INT NOT NULL,\n  FOREIGN KEY (character_id) REFERENCES characters(character_id)\n);\nQuestion: 인벤토리 아이템의 이름과 수량, 해당 아이템을 소유한 캐릭터의 클래스를 보여주세요.\ngt_sql: SELECT T2.item_name, T2.quantity, T1.character_class FROM characters AS T1 JOIN inventory_items AS T2 ON T1.character_id = T2.character_id;\ngen_sql: SELECT item_name, quantity, character_class\nFROM inventory_items\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT character_id FROM characters\nWHERE character_id = (SELECT charac ...
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-1463' coro=<APIRequest.call_api() done, defined at /home/woosungkim/projects/deep_learning/textbook/LLM/ch06/api_request_parallel_processor.py:302> exception=FileNotFoundError(2, 'No such file or directory')>
# Traceback (most recent call last):
#   File "/home/woosungkim/projects/deep_learning/textbook/LLM/ch06/api_request_parallel_processor.py", line 351, in call_api
#     append_to_jsonl(data, save_filepath)
#   File "/home/woosungkim/projects/deep_learning/textbook/LLM/ch06/api_request_parallel_processor.py", line 383, in append_to_jsonl
#     with open(filename, "a") as f:
#          ^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'results/text2sql_evaluation.jsonl'

# %%
df_sql = load_dataset("shangrilar/ko_text2sql", "origin")['train']
df_sql = df_sql.to_pandas()
df_sql = df_sql.dropna().sample(frac=1, random_state=42)
df_sql = df_sql.query("db_id != 1")

for idx, row in df_sql.iterrows():
    df_sql.loc[idx, 'text'] = make_prompt(row['context'], row['question'], row['answer'])

# !mkdir data
df_sql.to_csv('data/train.csv', index=False)

# %%
base_model = "beomi/Yi-Ko-6B"
finetuned_model = "yi-ko-6b-text2sql"

# !autotrain llm \
--train \
--model {base_model} \
--project-name {finetuned_model} \
--data-path data/ \
--text-column text \
--lr 2e-4 \
--batch_size 8 \
--epochs 1 \
--block-size 1024 \
--warmup-ratio 0.1 \
--lora-r 16 \
--lora-alpha 32 \
--lora-dropout 0.05 \
--weight-decay 0.01 \
--gradient-accumulation 8 \
--mixed-precision fp16 \
--use-peft \
--quantization int4 \
--trainer sft

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
from peft import LoraConfig, PeftModel

model_name = base_model
device_map = {"": 0}

# LoRA와 기초 모델 파라미터 합치기
base_model = AutoModelForCausalLM.from_pretrained(
    model_name,
    low_cpu_mem_usage=True,
    return_dict=True,
    torch_dtype=torch.float16,
    device_map=device_map
)
model = PeftModel.from_pretrained(base_model, finetuned_model)
model = model.merge_and_unload()

# 토크나이저 설정
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = 'right'

# 허깅페이스 허브에 모델 및 토크나이저 저장
model.push_to_hub(finetuned_model, use_temp_dir=False)
tokenizer.push_to_hub(finetuned_model, use_temp_dir=False)

# %%
model_name = "shangrilar/yi-ko-6b-text2sql"
hf_pipe = make_inference_pipeline(model_name)

hf_pipe(example, do_sample=False, return_full_text=False, max_length=1024, truncation=True)

# %%
# sql 생성 수행
gen_sqls = hf_pipe(df['prompt'].tolist(), do_sample=False, return_full_text=False, max_length=1024, truncation=True)
gen_sqls = [x[0]['generated_text'] for x in gen_sqls]
df['gen_sql'] = gen_sqls

# 평가를 위한 requests.jsonl 생성
eval_filepath = "text2sql_evaluation_finetuned.jsonl"
make_requests_for_gpt_evaluation(df, eval_filepath)
# GPT-4 평가 수행
# !python api_request_parallel_processor.py \
    --requests_filepath requests/{eval_filepath} \
    --save_filepath results/{eval_filepath} \
    --request_url https://api.openai.com/v1/chat/completions \
    --max_requests_per_minute 2500 \
    --max_tokens_per_minute 100000 \
    --token_encoding_name cl100k_base \
    --max_attempt 5 \
    --logging_level 20

# %% [markdown]
# ### 학습 데이터 정제와 미세 조정

# %%
clean_dataset = load_dataset("shangrilar/ko_text2sql", "clean")['train']
